# %% [markdown]
# Importing Required Modules

# %%
import pandas as pd
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# Opening Chrome

# %% [markdown]
# **Career Guide**

# %%
browser = webdriver.Chrome("chromedriver.exe")
browser.get("https://www.careerguide.com/career-options/")
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/3134474417.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# Categories

# %%
categories = browser.find_elements_by_class_name("c-font-bold")
category_list = []
for category in range(1,len(categories)-12):
    category_list.append(categories[category].text)
print('{0}\n\nNumber of categories: {1}'.format(category_list, len(category_list)))
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/4229364634.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   categories = browser.find_elements_by_class_name("c-font-bold")
# ['Aerospace & Aviation', 'Agriculture', 'Automobile / Autocomponents', 'Banking / Insurance & Finance', 'Beauty & Wellness Industry', 'Building & Construction', 'Building / Hardware & Home Furnishings', 'Chemicals & Pharmaceuticals', 'Commerce or Humanities Stream', 'Defense & Military', 'Designing & Art', 'Education / Skill Development', 'Electronics & Hardware', 'Emergency Services', 'Engineering & Technology', 'Exams and Syllabus', 'Food Processing', 'Gems & Jewellery', 'Handlooms & Handicrafts', 'Healthcare', 'Humanistic Studies', 'Information Technology / Software', 'Institutes in India', 'ITES / BPO', 'Law & Order', 'Leather & Leather Goods', 'Management & Marketing', 'Media / Entertainment & Animation', 'Organised Retail', 'Psychometric Career Test', 'Public Admin & Government', 'Real Estate', 'Science & Research', 'Sports', 'Study Abroad', 'Telecom', 'Textiles & Garments', 'Tourism / Hospitality & Travel', 'Transportation/Logistics/Warehousing & Packaging']
#
# Number of categories: 39

# %% [markdown]
# Subcategories

# %%
sub_categories = browser.find_elements_by_class_name("c-content-list-1")
sub_category_list = []
for sub_category in sub_categories:
    sub_category_list.append(sub_category.text.replace("\n",",").split(","))
print(sub_category_list)
len(sub_category_list)
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/1215922384.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   sub_categories = browser.find_elements_by_class_name("c-content-list-1")
# [['Airline Pilot', 'Aerospace Materials Specialist', 'Air Traffic Controller', 'Aircraft Cleaner', 'Aircraft Maintenance Technician', 'Aircraft Refueller', 'Terminal Operations Manager', 'Reservation and Ticketing Agent', 'Ramp Service Agent', 'Ground Operation Staff', 'Cabin Crew/Flight Attendant', 'Baggage and Cargo Handler', 'Avionics and ElectronicsTechnician', 'Airport security Executive', 'Aircraft Structures Technician', 'Commercial Pilot'], ['Agriculture & Allied Fields', 'Biological Scientist', 'Dietitian', 'Environmental scientist', 'Fishery Scientist', 'Food Technologists', 'Geographers  ', 'Geologists', 'Indian Forest Service Officer  ', 'Meteorologist', 'Nutritionists', 'Oceanographers', 'Zoologists', 'Crop Farmer', 'Farm Eqipment Mechanic', 'Fisheries', 'Gardener', 'Greenhouse Fitter', 'Horticulture Farmer', 'Micro Irrigation Technician', 'Pesticide Handler', 'Poultry Farmer', 'Pump Operator', 'Tea Plantation Worker', 'Tractor Servicing/Operator', 'Vegetable Farmer'], ['CNC Operator', 'Lathe Operator', 'Maintainance Technician', 'Spare Part Opertaion Executive', 'Washer'], ['Actuary', 'Bank Officer', 'Chartered Accountant', 'Company Secretary', 'Cost Accountant', 'Financial Planners', 'Insurance Officer', 'Investment Analyst', 'Research Analyst', 'Security Analyst', 'Stock Brokers', 'Underwriter', 'Trading Advisor', 'Accountant', 'Bank Probationary Officer', 'Bank Clerks', 'Bank Specialist Officer', 'Insurance Claims Manager', 'Collections & Recovery Manager', 'Cashiers', 'Branch Manager', 'Chief Financial Officer (CFO)', 'Chartered Financial Analyst (CFA)', 'Economist', 'DSA/Sales Executives', 'Investment Banker', 'Phone Banking Officer', 'Ratings Analyst', 'Private Equity / Venture Capital', 'Relationship Manager', 'Budget Analyst', 'Loan Officer'], ['Makeup Artist'], ['Bar Bender', 'Construction Worker', 'Mason', 'Plumber', 'Road Worker', 'Welder', 'Supervisors', 'Foremen', 'Crane operators', 'Electricians', 'Carpenters'], ['Building hardware and home furnishings', 'Building Carpenter', 'Ceiling Fixer', 'Civil Engineering Technician', 'Draftsman', 'Earth work excavator', 'Electrical Wiremen/Technician', 'Fitter', 'Interior Designer', 'Paint Sprayer', 'Scaffolder', 'Sheet Metal Worker', 'Tiler', 'Turner'], ['Chemical Technician', 'Equipment Operator', 'Industrial Chemical Manufacturing Attendant', 'lab Attendant', 'Manufacturing Assistant', 'Chemical and Pharmaceutical Operators', 'Process attendant-Chemical Plants', 'Production and QC Technician'], ['Commerce'], ['Air Force Related Careers', 'Army Related Careers', 'Navy Related Careers', 'Police Service- Border Security Force', 'Police Service - Central Reserve Police Force'], ['Accessory Designers', 'Architect', 'Beautician', 'Fashion Designer', 'Footwear Designer', 'Furniture Designer', 'Gemologist', 'Graphics Designer', 'Illustrator', 'Interior Designers', 'Jewellery Designers', 'Photographer', 'Textile Designers', 'Product Designer', 'Retail and Exhibition Designer', 'Animation Film Maker', 'User Experience Designer', 'Life Style Accessory Designer', 'Toy and game Designer', 'Transportation and Automobile Designer', 'Floral Designer', 'Landscape Architect', 'Sculptor'], ['School Psychologists', 'Clinical Psychologists', 'Foreign Langauge Teacher', 'Lecturers', 'Librarian', 'Physical Education Instructor/Coach', 'Principal', 'Professors', 'School Teacher', 'Special Educators', 'Translator', 'Tutor'], ['Desktop Support engineer', 'Server Support engineer', 'Set Top Box Installer/Service', 'Pick and Place Assembly Operator', 'Network Planning / Infrastructure Eng.', 'Switching/ Router Engineer', 'Test Engineer', 'Technical Support Engineer', 'Maintainence Engineer', 'Power Eelectrician', 'Mechanic - TV/Radio', 'Refrigeration & Air Conditioning Mechanic', 'Batttery Repairer', 'Electroplater', 'Lineman/Wireman', 'Cable Jointer'], ['Fire Fighter', 'Risk Management Specialist'], ['Instrumentation Engineer', 'Mechanical Engineer', 'Aeronautical Engineer', 'Agricu ...
# 39

# %% [markdown]
# **Linkedn**

# %%
browser.get("https://www.linkedin.com")

# %% [markdown]
# Log in Details
#
# *****Note** : Input function is used for login

# %%
username = browser.find_element_by_id("session_key")
username.send_keys(input("Enter User Name/ Email id/ Phone Number: "))
password = browser.find_element_by_id("session_password")
password.send_keys(input("Enter your password: "))
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/611500585.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username = browser.find_element_by_id("session_key")
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/611500585.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password = browser.find_element_by_id("session_password")

# %% [markdown]
# Login Button

# %%
login_button = browser.find_element_by_class_name("sign-in-form__submit-button")
login_button.click()
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/1427998485.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   login_button = browser.find_element_by_class_name("sign-in-form__submit-button")

# %%
browser.get("https://www.linkedin.com/jobs/search")

# %%
search_jobs = browser.find_element_by_id("jobs-search-box-keyword-id-ember31")
search_jobs_by_location = browser.find_element_by_id("jobs-search-box-location-id-ember31")
search_jobs.send_keys(category_list[0])
search_button = browser.find_element_by_class_name("jobs-search-box__submit-button")
search_button.click()
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/78041438.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_jobs = browser.find_element_by_id("jobs-search-box-keyword-id-ember31")
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/78041438.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_jobs_by_location = browser.find_element_by_id("jobs-search-box-location-id-ember31")
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/78041438.py:4: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   search_button = browser.find_element_by_class_name("jobs-search-box__submit-button")

# %% [markdown]
# Job Search by category from carrierguide.com

# %%
searched_jobs = browser.find_elements_by_class_name("full-width.artdeco-entity-lockup__title.ember-view")
company_job1 = []
for i in searched_jobs:
    company_job1.append(i.text)
search_jobs.clear()
search_jobs_by_location.clear()
print('Job Category:',category_list[0])
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/1257207842.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   searched_jobs = browser.find_elements_by_class_name("full-width.artdeco-entity-lockup__title.ember-view")
# Job Category: Aerospace & Aviation

# %% [markdown]
# Job Position

# %%
print('{0}\n\nNumber of Jobs: {1}'.format(company_job1, len(company_job1)))
# Out:
# ['Graduate Engineer', 'Graduate Engineer', 'Associate Engineer', 'Graduate Engineer', 'Field Services Representative', 'Graduate Engineer', 'Associate Engineer', 'Mechanical Design Engineer', 'Business Analyst (FCAM: Aircraft Fuel Efficiency Management)', 'Lead Engineer', 'Associate Mechanical Design and Analysis Engineer', 'Staff Engineer', 'Sr Lead Engineer', 'Lead Engineer', 'Lead Engineer, Structrl Engrg', 'Lead Engineer, AeroThermFluid', 'Project Manager - Operations', 'Lead Engineer, Structrl Engrg', 'Sr Lead Engineer', 'Lead Engineer', 'Software Architect', 'Lead Engineer', 'Principal Engineer', 'Lead Engineer', 'Lead Engineer/ Senior Lead Engineer']
#
# Number of Jobs: 25

# %% [markdown]
# Job States

# %%
location = browser.find_elements_by_class_name("job-card-container__metadata-item")
location_name = []
for i in range(len(location)):
    location_name.append(location[i].text)

for y in location_name:
    if y == 'Remote' or y == 'On-site' or y == 'Hybrid':
        location_name.remove(y)

state_name = []
for i in location_name:
    loc = i.split(",")[1:-1]
    for q in loc:
        state_name.append(q[1:])

print('{0}\n\nNumber of state searches: {1}'.format(state_name, len(state_name)))
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/1537624669.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   location = browser.find_elements_by_class_name("job-card-container__metadata-item")
# ['Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Karnataka', 'Delhi', 'Karnataka', 'Telangana', 'Karnataka', 'Karnataka', 'Telangana', 'Karnataka', 'Karnataka', 'Karnataka']
#
# Number of state searches: 24

# %% [markdown]
# Job search by **state** name and **subcategory**

# %%
search_jobs_by_subcategory = browser.find_element_by_id("jobs-search-box-keyword-id-ember31")
search_jobs_by_subcategory.send_keys(sub_category_list[0][1])
search_jobs_by_state = browser.find_element_by_id("jobs-search-box-location-id-ember31")
search_jobs_by_state.send_keys(state_name[0])
search_button = browser.find_element_by_class_name("jobs-search-box__submit-button")
search_button.click()
search_jobs_by_subcategory.clear()
search_jobs_by_state.clear()
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/263360336.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_jobs_by_subcategory = browser.find_element_by_id("jobs-search-box-keyword-id-ember31")
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/263360336.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_jobs_by_state = browser.find_element_by_id("jobs-search-box-location-id-ember31")
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/263360336.py:5: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   search_button = browser.find_element_by_class_name("jobs-search-box__submit-button")

# %% [markdown]
# Company offering Job at

# %%
company_offering_job = browser.find_elements_by_class_name("job-card-container__metadata-item.job-card-container__metadata-item--workplace-type")
company_offering_job_list = []
for i in company_offering_job:
    company_offering_job_list.append(i.text)
    
print('{0}\n\nCount of companies offering jobs at: {1}'.format(company_offering_job_list, len(company_offering_job_list)))
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/1274419993.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   company_offering_job = browser.find_elements_by_class_name("job-card-container__metadata-item.job-card-container__metadata-item--workplace-type")
# ['On-site', 'On-site', 'On-site', 'On-site', 'On-site', 'On-site', 'On-site', 'On-site', 'On-site', 'On-site', 'Remote', 'Remote']
#
# Count of companies offering jobs at: 12

# %% [markdown]
# Company

# %%
company = browser.find_elements_by_class_name("job-card-container__company-name")
company_name = []
for i in company:
    company_name.append(i.text)

print('{0}\n\nNumber of companies: {1}'.format(company_name, len(company)))
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/2395865426.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   company = browser.find_elements_by_class_name("job-card-container__company-name")
# ['Alstom', 'Expleo Group', 'Columbia Sportswear Company', 'IDEAPOKE TECHNOLOGIES PRIVATE LIMITED', 'Accenture in India', 'Flex', 'Kennametal', 'GadflyZone', 'Log9 Materials', 'RGBSI', 'Acuity Knowledge Partners', 'Kennametal', 'Cactus Communications', 'Cactus Communications']
#
# Number of companies: 14

# %% [markdown]
# Job Location

# %%
location = browser.find_elements_by_class_name("job-card-container__metadata-item")
location_name = []
for i in range(len(location)):
    location_name.append(location[i].text)

for y in location_name:
    if y == 'Remote' or y == 'On-site' or y == 'Hybrid':
        location_name.remove(y)

print('{0}\n\nNumber of locations: {1}'.format(location_name, len(location_name)))
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/3580603036.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   location = browser.find_elements_by_class_name("job-card-container__metadata-item")
# ['Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bangalore Urban, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'Bengaluru, Karnataka, India', 'India']
#
# Number of locations: 14

# %% [markdown]
# Search

# %% [markdown]
# Job Discription

# %%
job_disc = browser.find_elements_by_class_name("jobs-description-content__text--stretch")
discription = []
for i in job_disc:
    discription.append(i.text)
for j in discription:
    print(j)
# Out:
# Req ID: 157401
#
# We create smart innovations to meet the mobility challenges of today and tomorrow. We design and manufacture a complete range of transportation systems, from high-speed trains to electric buses and driverless trains, as well as infrastructure, signalling and digital mobility solutions. Joining us means joining a truly global community of more than 75 000 people dedicated to solving real-world mobility challenges and achieving international projects with sustainable local impact.
#
# Material Planning Associate
#
# About Alstom In India
#
# Alstom has established a strong presence in India. Currently, the company is executing metro projects in several Indian cities including Chennai, Kochi and Lucknow where it is supplying Rolling Stock manufactured out its state of the art facility at SriCity in Andhra Pradesh. In the Mainline space, Alstom is executing Signaling & Power Supply Systems for the 343 Km. section on World Bank funded Eastern Dedicated Freight Corridor. Phase 1 in the construction of the new electric locomotive factory for manufacturing and supply of 800 units of 12000HP locomotives is also complete at Madhepura, Bihar while the depot at Saharanpur, Uttar Pradesh is ready to commence operation. Alstom has set up an Engineering Centre of Excellence in Bengaluru, and this coupled with a strong manufacturing base as well as localized supply chains, is uniquely positioned to serve customers across the globe. Today, Alstom in India employs close to 3600 people and in line with Government of India’s ‘Make in India’ policy initiative, Alstom has been investing heavily in the country in producing world class rolling stock, components, design, research and development to not only serve the domestic market, but also rest of the world. www.alstom.com/ India
#
# Job Title: Material Planning Associate
#
# Purpose of Role:
#
# Individual role in Supply Chain Solutions Centre responsible for execution of Materials Planning Processes that are the scope of the Solutions Centre Team.
#
# Reports directly to:
#
# Supply Chain Solutions Centre Team Leader
#
# NETWORKS & LINKS
#
# External
# External Providers (Suppliers)
#
# Internal
# Site Material Planner
# Site Buyer
# Key User & Regional Business Process Experts
# Supply Chain Solutions Centre Team Leader
#
# RESPONSIBILITIES:
# Creates Material Planning documents in GSI (Alstom ERP Solution) & communicate the Alstom delivery requirement to suppliers.
# Receives the Supplier delivery confirmation against the Alstom delivery needs & to ensure the right information is available in system for Site Material Planner reference.
# Co-ordinates with Internal & External networks to execute the defined task within the agreed Service Level Agreements (SLA) set between SC2 and Sites.
# Acts as a representative of the site, when interacting with Suppliers
#
# Skills & Education
# Academic diploma / degree in any subject. Academic diploma / Academic diploma in Supply Chain in Supply Chain
# Languages: English fluent. Hindi + knowledge of local language
# Experience: Should have at least 3 years of relevant experience (combined)
# Should be exposed to modern logistics principles for efficient transportation management and distribution control
# Understands Material Requirement Planning & can extract MIS from a Supply Chain Information System
# Hands on Supplier Relationship Management
# Strong Collaboration & Communication skills
# Strong Analytical Skills
# Adequate exposure to Tools like MS EXCEL & BI
#
# An agile, inclusive and responsible culture is the foundation of our company where diverse people are offered excellent opportunities to grow, learn and advance in their careers. We are committed to encouraging our employees to reach their full potential, while valuing and respecting them as individuals.
#
# Job Type: Experienced
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/4175048403.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   job_disc = browser.find_elements_by_class_name("jobs-description-content__text--stretch")

# %% [markdown]
# Company Page

# %%
comp_page = browser.find_element_by_class_name("artdeco-entity-lockup__title.ember-view.t-20")
comp_page.click()
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/1893732981.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   comp_page = browser.find_element_by_class_name("artdeco-entity-lockup__title.ember-view.t-20")

# %%
company_page_about = browser.find_elements_by_class_name("org-page-navigation__item.m0")
company_page_about[1].click()
# Out:
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/4259813539.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   company_page_about = browser.find_elements_by_class_name("org-page-navigation__item.m0")

# %% [markdown]
# Company Discription

# %%
company_discription = browser.find_element_by_class_name("break-words.white-space-pre-wrap.mb5.text-body-small.t-black--light")
company_discription_list = []
company_discription_list.append(company_discription.text)
for i in company_discription_list:
    print(i)
# Out:
# Leading societies to a low carbon future, Alstom develops and markets mobility solutions that provide the sustainable foundations for the future of transportation. Alstom’s product portfolio ranges from high-speed trains, metros, monorail and trams to integrated systems, customised services, infrastructure, signalling and digital mobility solutions. Alstom has 150,000 vehicles in commercial service worldwide. With Bombardier Transportation joining Alstom on January 29, 2021, the enlarged Group’s combined proforma revenue amounts to €14 billion for the 12-month period ended March 31, 2021. Headquartered in France, Alstom is now present in 70 countries and employs more than 70,000 people. www.alstom.com
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/2699399640.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   company_discription = browser.find_element_by_class_name("break-words.white-space-pre-wrap.mb5.text-body-small.t-black--light")

# %% [markdown]
# Number of Employees in Company

# %%
employee = browser.find_element_by_class_name("text-body-small.t-black--light.mb1")
employee_list = []
employee_list.append(employee.text)
print(employee_list)
# Out:
# ['10,001+ employees']
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/893757419.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   employee = browser.find_element_by_class_name("text-body-small.t-black--light.mb1")

# %% [markdown]
# Company Location

# %%
company_location = browser.find_elements_by_class_name("t-14.t-black--light.t-normal.break-words")
company_location_list = []
for i in company_location:
    company_location_list.append(i.text)
print(company_location_list)
# Out:
# ['48, rue Albert Dhalenne, Saint-Ouen, 93 400, FR']
# C:\Users\AARTIR~1\AppData\Local\Temp/ipykernel_23256/2382090406.py:1: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   company_location = browser.find_elements_by_class_name("t-14.t-black--light.t-normal.break-words")

# %% [markdown]
# Data Frames

# %% [markdown]
# Categories and Sub Categories

# %%
col1 = ["Categories", "Sub Categories", ]
df1 = pd.DataFrame()
dict = {}
Catagories = category_list
Sub_Catagories = sub_category_list
for i in range(len(Catagories)):
    for x in range(len(Catagories)):
        dict[Catagories[i]] = Sub_Catagories[i][0:]

df1.append(dict, ignore_index="True")
# Out:
#                                 Aerospace & Aviation  \
# 0  [Airline Pilot, Aerospace Materials Specialist...
#
#                                          Agriculture  \
# 0  [Agriculture & Allied Fields, Biological Scien...
#
#                          Automobile / Autocomponents  \
# 0  [CNC Operator, Lathe Operator, Maintainance Te...
#
#                        Banking / Insurance & Finance  \
# 0  [Actuary, Bank Officer, Chartered Accountant, ...
#
#   Beauty & Wellness Industry  \
# 0            [Makeup Artist]
#
#                              Building & Construction  \
# 0  [Bar Bender, Construction Worker, Mason, Plumb...
#
#               Building / Hardware & Home Furnishings  \
# 0  [Building hardware and home furnishings, Build...
#
#                          Chemicals & Pharmaceuticals  \
# 0  [Chemical Technician, Equipment Operator, Indu...
#
#   Commerce or Humanities Stream  \
# 0                    [Commerce]
#
#                                   Defense & Military  ...  \
# 0  [Air Force Related Careers, Army Related Caree...  ...
#
#   Psychometric Career Test                          Public Admin & Government  \
# 0      [Ideal Career Test]  [Indian Administrative Services, Indian Foreig...
#
#             Real Estate                                 Science & Research  \
# 0  [Real Estate Broker]  [Astronomer, Biologists, Genetics Scientists, ...
#
#                                               Sports  \
# 0  [Sportsperson, Coach, Sports Physiotherapist, ...
#
#                                         Study Abroad  \
# 0  [Study in USA, Study in Canada, Study in UK, S...
#
#                                              Telecom  \
# 0  [BSS Engineer, CCE (Repair Center), Cluster In...
#
#                                  Textiles & Garments  \
# 0  [Batik Printing Specialist, Textile Machine Op...
#
#                       Tourism / Hospitality & Travel  \
# 0  [Cabin Crew, Chef, Hotel Managers, Interpreter...
#
#     Transportation/Logistics/Warehousing & Packaging
# 0  [Loader, Courier Personal, Operation Superisor...
#
# [1 rows x 39 columns]

# %%
df1.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Particular sub category

# %%
col2 = ["Sub Categories", "Job Positions", "Company Offering Job", "Company_Name", "State", "Location Name"]
df2 = pd.DataFrame({"Sub Catagories":sub_category_list[0][0], "Job Positions":company_job1[:5], "Company Offering Job":company_offering_job_list[:5], "Company_Name":company_name[:5], "State":state_name[:5], "Location Name":location_name[:5]})

# %%
df2.head()
# Out:
#   Sub Catagories                  Job Positions Company Offering Job  \
# 0  Airline Pilot              Graduate Engineer              On-site
# 1  Airline Pilot              Graduate Engineer              On-site
# 2  Airline Pilot             Associate Engineer              On-site
# 3  Airline Pilot              Graduate Engineer              On-site
# 4  Airline Pilot  Field Services Representative              On-site
#
#                             Company_Name      State  \
# 0                                 Alstom  Karnataka
# 1                           Expleo Group  Karnataka
# 2            Columbia Sportswear Company  Karnataka
# 3  IDEAPOKE TECHNOLOGIES PRIVATE LIMITED  Karnataka
# 4                     Accenture in India  Karnataka
#
#                  Location Name
# 0  Bengaluru, Karnataka, India
# 1  Bengaluru, Karnataka, India
# 2  Bengaluru, Karnataka, India
# 3  Bengaluru, Karnataka, India
# 4  Bengaluru, Karnataka, India

# %%
col3 = ["Categories", "Job Positions", "Company Offering Job", "Company_Name", "Location Name", "Job Discription", "Company Discription", "Employee List", "Company Location List"]
df3 = pd.DataFrame({"Catagories":category_list[:1], "Job Positions":company_job1[:1], "Company Offering Job":company_offering_job_list[:1], "Company_Name":company_name[:1], "Location Name":location_name[:1], "State":state_name[:1], "Job Discription":discription[:1], "Company Discription":company_discription_list[:1], "Employee":employee_list[:1], "Company Location":company_location_list[:1]})

# %% [markdown]
# Particular Job and its details

# %%
df3.head()
# Out:
#              Catagories      Job Positions Company Offering Job Company_Name  \
# 0  Aerospace & Aviation  Graduate Engineer              On-site       Alstom
#
#                  Location Name      State  \
# 0  Bengaluru, Karnataka, India  Karnataka
#
#                                      Job Discription  \
# 0  Req ID: 157401\n\nWe create smart innovations ...
#
#                                  Company Discription           Employee  \
# 0  Leading societies to a low carbon future, Alst...  10,001+ employees
#
#                                   Company Location
# 0  48, rue Albert Dhalenne, Saint-Ouen, 93 400, FR

# %% [markdown]
# Convert DataFrame to CSV files

# %%
df1.to_csv("Catagories_and_Sub_Categories.csv")
df2.to_csv("Particular_Sub_Categary.csv")
df3.to_csv("Particular_Job_and_its_details.csv")

# %% [markdown]
# **MySQL**
#
# Connecting with MySQL, Creating Databas and Tables

# %% [markdown]
# Table 1
#
# catagories_and_sub_categories

# %%
import mysql.connector
from mysql import *
def DataframeToSql1(dataframe):
    # Exeption handling start
    # create new connection
    conn = mysql.connector.connect(host=input("Enter host: "), user=input("Enter user: "), password=input("Enter Password: "), database=input("Enter Database name: "), charset="utf8")
    # create new cursor
    cur = conn.cursor()
    # first execute query to make Catagories_and_Sub_Categories table empty so that we can insert new updated dataframe
    cur.execute("delete from Catagories_and_Sub_Categories")
    conn.commit() # to make changes permanently
    # start insertion of data from dataframe to mysql
    for (row,rs) in dataframe.iterrows():
        Aerospace_and_Aviation = rs[0]
        Agriculture = rs[1]
        Automobile_or_Autocomponents = rs[2]
        Banking_or_Insurance_and_Finance = rs[3]
        Beauty_and_Wellness_Industry = rs[4]
        Building_and_Construction = rs[5]
        Building_or_Hardware_and_Home_Furnishings= rs[6]
        Chemicals_and_Pharmaceuticals= rs[7]
        Commerce_or_Humanities_Stream= rs[8]
        Defense_and_Military= rs[9]
        Designing_and_Art= rs[10]
        Education_or_skill_Development= rs[11]
        Electronics_and_Hardware= rs[12]
        Emergency_Services= rs[13]
        Engineering_and_Technology= rs[14]
        Exams_and_Syllabus= rs[15]
        Food_Processing= rs[16]
        Gems_and_Jewellery= rs[17]
        Handlooms_and_Handicrafts= rs[18]
        Healthcare= rs[19]
        Humanistic_Studies= rs[20]
        Information_Technology_or_Software= rs[21]
        Institutes_in_India= rs[22]
        ITES_or_BPO= rs[23]
        Law_and_Order= rs[24]
        Leather_and_Leather_Goods= rs[25]
        Management_and_Marketing= rs[26]
        Media_or_Entertainment_and_Animation= rs[27]
        Organised_Retail= rs[28]
        Psychometric_Career_Test= rs[29]
        Public_Admin_and_Government= rs[30]
        Real_Estate= rs[31]
        Science_and_Research= rs[32]
        Sports= rs[33]
        Study_Abroad= rs[34]
        Telecom= rs[35]
        Textiles_and_Garments= rs[36]
        Tourism_or_Hospitality_and_Travel= rs[37]
        Transportation_or_Logistics_or_Warehousing_and_Packaging= rs[38]
        query = "insert into Catagories_and_Sub_Categories values("+Aerospace_and_Aviation+","+Agriculture+","+Automobile_or_Autocomponents+","+Banking_or_Insurance_and_Finance+","+Beauty_and_Wellness_Industry+","+Building_and_Construction+","+Building_or_Hardware_and_Home_Furnishings+","+Chemicals_and_Pharmaceuticals+","+Commerce_or_Humanities_Stream+","+Defense_and_Military+","+Designing_and_Art+","+Education_or_skill_Development+","+Electronics_and_Hardware+","+Emergency_Services+","+Engineering_and_Technology+","+Exams_and_Syllabus+","+Food_Processing+","+Gems_and_Jewellery+","+Handlooms_and_Handicrafts+","+Healthcare+","+Humanistic_Studies+","+Information_Technology_or_Software+","+Institutes_in_India+","+ITES_or_BPO+","+Law_and_Order+","+Leather_and_Leather_Goods+","+Management_and_Marketing+","+Media_or_Entertainment_and_Animation+","+Organised_Retail+","+Psychometric_Career_Test+","+Public_Admin_and_Government+","+Real_Estate+","+Science_and_Research+","+Sports+","+Study_Abroad+","+Telecom+","+Textiles_and_Garments+","+Tourism_or_Hospitality_and_Travel+","+Transportation_or_Logistics_or_Warehousing_and_Packaging+")"
        # cur.execute(query)
    # cur.commit()
    cur.close()
    if conn.is_connected():
        conn.close()

# main program
datafram = pd.read_csv("Catagories_and_Sub_Categories.csv")
DataframeToSql1(datafram)
print("successful")
# Out:
# successful

# %% [markdown]
# Table 2
#
# catagories_and_sub_categories

# %%
def DataframeToSql2(dataframe1):
    # Exeption handling start
    # create new connection
    conn = mysql.connector.connect(host="localhost", user="root", password="Mysql@940363", database="web_scraping", charset="utf8")
    # create new cursor
    cur = conn.cursor()
    # first execute query to make Catagories_and_Sub_Categories table empty so that we can insert new updated dataframe
    cur.execute("delete from Particular_Sub_Categary")
    conn.commit() # to make changes permanently
    # start insertion of data from dataframe to mysql
    for (row,rs) in dataframe1.iterrows():
        Sub_Catagories = rs[0]
        Job_Positions = rs[1]
        Company_Offering_Job = rs[2]
        Company_Name = rs[3]	
        State = rs[4]
        Location_Name = rs[5]
        query = "insert into Particular_Sub_Categary values("+Sub_Catagories+","+Job_Positions+","+Company_Offering_Job+","+Company_Name+","+State+","+Location_Name+")"
        cur.execute(query)
    # cur.commit()
    cur.close()
    if conn.is_connected():
        conn.close()

# main program
datafram1 = pd.read_csv("Particular_Sub_Categary.csv")
DataframeToSql2(datafram1)
print(datafram1)
print("successful")

# %% [markdown]
# Table 3
#
# particular_sub_categary

# %%
def DataframeToSql3(dataframe2):
    # Exeption handling start
    # create new connection
    conn = mysql.connector.connect(host="localhost", user="root", password="Mysql@940363", database="web_scraping", charset="utf8")
    # create new cursor
    cur = conn.cursor()
    conn.corsor("select * from particular_sub_categary")
    # first execute query to make Catagories_and_Sub_Categories table empty so that we can insert new updated dataframe
    cur.execute("delete from Particular_Sub_Categary")
    conn.commit() # to make changes permanently
    # start insertion of data from dataframe to mysql
    for (row,rs) in dataframe2.iterrows():
        Catagories = rs[0]
        Job_Positions = rs[1]
        Company_Offering_Job = rs[2]
        Company_Name = rs[3]
        Location_Name = rs[4]
        State = rs[5]
        Job_Discription = rs[6]
        Company_Discription = rs[7]
        Employee = rs[8]
        Company_Location = rs[9]
        query = "insert into Particular_Job_and_its_details values("+Catagories+","+Job_Positions+","+Company_Offering_Job+","+Company_Name+","+Location_Name+","+State+","+Job_Discription+","+Company_Discription+","+Employee+","+Company_Location+")"
        cur.execute(query)
    # cur.commit()
    cur.close()
    if conn.is_connected():
        conn.close()

# main program
datafram2 = pd.read_csv("Particular_Job_and_its_details.csv")
DataframeToSql3(datafram2)
print("successful")

# %% [markdown]
# **Display Tables from Mysql**

# %% [markdown]
# Name of Tables in Database

# %%
conn = mysql.connector.connect(host="localhost", user="root", password="Mysql@940363", database="web_scraping", charset="utf8")
# create new cursor
cur = conn.cursor()
cur.execute("SHOW TABLES")
for table_name in cur:
   print(table_name)
# Out:
# ('catagories_and_sub_categories',)
# ('particular_job_and_its_details',)
# ('particular_sub_categary',)

# %% [markdown]
# Table 1

# %%
cur.execute("SELECT * FROM catagories_and_sub_categories")
myresult = cur.fetchall()
for table in myresult:
   print(table)

# %% [markdown]
# Table 2

# %%
cur.execute("SELECT * FROM particular_job_and_its_details")
myresult = cur.fetchall()
for table in myresult:
   print(table)
# Out:
# (0, 'Aerospace & Aviation', 'Graduate Engineer', 'On-site', 'Alstom', 'Bengaluru, Karnataka, India', 'Karnataka', 'Req ID: 157401\n\nWe create smart innovations to meet the mobility challenges of today and tomorrow. We design and manufacture a complete range of transportation systems, from high-speed trains to electric buses and driverless trains, as well as infrastructure, signalling and digital mobility solutions. Joining us means joining a truly global community of more than 75 000 people dedicated to solving real-world mobility challenges and achieving international projects with sustainable local impact.\n\nMaterial Planning Associate\n\nAbout Alstom In India\n\nAlstom has established a strong presence in India. Currently, the company is executing metro projects in several Indian cities including Chennai, Kochi and Lucknow where it is supplying Rolling Stock manufactured out its state of the art facility at SriCity in Andhra Pradesh. In the Mainline space, Alstom is executing Signaling & Power Supply Systems for the 343 Km. section on World Bank funded Eastern Dedicated Freight Corridor. Phase 1 in the construction of the new electric locomotive factory for manufacturing and supply of 800 units of 12000HP locomotives is also complete at Madhepura, Bihar while the depot at Saharanpur, Uttar Pradesh is ready to commence operation. Alstom has set up an Engineering Centre of Excellence in Bengaluru, and this coupled with a strong manufacturing base as well as localized supply chains, is uniquely positioned to serve customers across the globe. Today, Alstom in India employs close to 3600 people and in line with Government of Indiaâ€™s â€˜Make in Indiaâ€™ policy initiative, Alstom has been investing heavily in the country in producing world class rolling stock, components, design, research and development to not only serve the domestic market, but also rest of the world. www.alstom.com/ India\n\nJob Title: Material Planning Associate\n\nPurpose of Role:\n\nIndividual role in Supply Chain Solutions Centre responsible for execution of Materials Planning Processes that are the scope of the Solutions Centre Team.\n\nReports directly to:\n\nSupply Chain Solutions Centre Team Leader\n\nNETWORKS & LINKS\n\nExternal\nExternal Providers (Suppliers)\n\nInternal\nSite Material Planner\nSite Buyer\nKey User & Regional Business Process Experts\nSupply Chain Solutions Centre Team Leader\n\nRESPONSIBILITIES:\nCreates Material Planning documents in GSI (Alstom ERP Solution) & communicate the Alstom delivery requirement to suppliers.\nReceives the Supplier delivery confirmation against the Alstom delivery needs & to ensure the right information is available in system for Site Material Planner reference.\nCo-ordinates with Internal & External networks to execute the defined task within the agreed Service Level Agreements (SLA) set between SC2 and Sites.\nActs as a representative of the site, when interacting with Suppliers\n\nSkills & Education\nAcademic diploma / degree in any subject. Academic diploma / Academic diploma in Supply Chain in Supply Chain\nLanguages: English fluent. Hindi + knowledge of local language\nExperience: Should have at least 3 years of relevant experience (combined)\nShould be exposed to modern logistics principles for efficient transportation management and distribution control\nUnderstands Material Requirement Planning & can extract MIS from a Supply Chain Information System\nHands on Supplier Relationship Management\nStrong Collaboration & Communication skills\nStrong Analytical Skills\nAdequate exposure to Tools like MS EXCEL & BI\n\nAn agile, inclusive and responsible culture is the foundation of our company where diverse people are offered excellent opportunities to grow, learn and advance in their careers. We are committed to encouraging our employees to reach their full potential, while valuing and respecting them as individuals.\n\nJob Type: Experienced', 'Leading societies to a low carbon future, Alstom develop ...

# %% [markdown]
# Table 3

# %%
cur.execute("SELECT * FROM particular_sub_categary")
myresult = cur.fetchall()
for table in myresult:
   print(table)
# Out:
# (0, 'Airline Pilot', 'Graduate Engineer', 'On-site', 'Alstom', 'Karnataka', 'Bengaluru, Karnataka, India')
# (1, 'Airline Pilot', 'Graduate Engineer', 'On-site', 'Expleo Group', 'Karnataka', 'Bengaluru, Karnataka, India')
# (2, 'Airline Pilot', 'Associate Engineer', 'On-site', 'Columbia Sportswear Company', 'Karnataka', 'Bengaluru, Karnataka, India')
# (3, 'Airline Pilot', 'Graduate Engineer', 'On-site', 'IDEAPOKE TECHNOLOGIES PRIVATE LIMITED', 'Karnataka', 'Bengaluru, Karnataka, India')
# (4, 'Airline Pilot', 'Field Services Representative', 'On-site', 'Accenture in India', 'Karnataka', 'Bengaluru, Karnataka, India')
